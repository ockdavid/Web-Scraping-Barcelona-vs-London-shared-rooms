# %%
# !pip install more-itertools
# Out:
# ...
#   Using cached more_itertools-9.0.0-py3-none-any.whl (52 kB)
# ...

# %%
import pandas as pd
import nums_from_string

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
import nums_from_string

ser = Service("./chromedriver")
options = Options()
options.headless = True
options.add_argument("--window-size=1920,1200")
def get_links():
    links = []
    driver = webdriver.Chrome(options=options, service=ser)
    driver.get("https://badi.com/es/s/Barcelona--Espa%C3%B1a?bounds=41.4682974272428,2.22804492421789;41.31703848925413,2.052333262952554&center=41.3873974,2.168568&d=11.164609446567885&city=Barcelona&pid=ChIJ5TCOcRaYpBIRCmZHTz37sEQ&z=12")
    for i in range(8): #cada uno son 25 links, antes era 8
        enlaces = driver.find_elements(By.XPATH,"//a[contains(@data-qa, 'room-card-link')]")
        for a in enlaces:
            links.append(a.get_attribute('href')) 
        nb = driver.find_element(By.XPATH, "//button[contains(@class, 'sc-9fxd19-1 jEzqfk')]")
        nb.click()
        time.sleep(2)
    df = pd.DataFrame(links)
    df = df.rename(columns={0: 'urls'})
    df.to_csv('urls_t_badi.csv')
    driver.quit()
    print('DOOONEEEE')
    return

# %%
get_links()
# Out:
# DOOONEEEE

# %%
def get_addresses():
    inicio = time.time()
    prop_dict_list = []
    
    df = pd.read_csv('urls_t_badi.csv')
    options = Options()
    options.headless = True
    options.add_argument("--window-size=1920,1200")
    driver = webdriver.Chrome('./chromedriver_mac64/chromedriver', options=options)
    for i in df['urls']:
        print(i)
        prop_dict = {}
        page = driver.get(i)

        try: 
            tamanho_html = driver.find_element(By.XPATH,"//p[contains(@data-qa, 'section-abstract-icon-label-area')]").text
            precio_html = driver.find_element(By.XPATH,"//h4[contains(@data-qa, 'room-details-current-price')]").text
        except:
            j=0
        
        print(precio_html)
        tamanho_float = float(tamanho_str[:-2])
        precio_str = precio_html[:-4]
        print(precio_str)
        precio_float = float(precio_str.replace('.', '').replace(',', '').replace('€', ''))
        print(precio_float)
            
        precio_x_metro = precio_float/tamanho_float
        prop_dict['precio_euros'] = precio_float
        prop_dict['tamanho'] = tamanho_float
        prop_dict['Barcelona'] = precio_x_metro

        prop_dict_list.append(prop_dict)
        time.sleep(1)
    df = pd.DataFrame(prop_dict_list)
    #df = df.rename(columns={0: 'addresses'})
    print(fin-inicio)
    print(df)
    df.to_csv('df_precios_badi.csv')
    driver.quit()
    fin = time.time()
    print(fin-inicio)
    return df

# %%
get_addresses()
# Out:
# C:\Users\ockda\AppData\Local\Temp\ipykernel_4812\3813149332.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver_mac64/chromedriver', options=options)
# https://badi.com/es/room/995730?et-room-view-source=search-feed
# 1.620 €/mes
# 1.620 €
# 1620.0
# https://badi.com/es/room/1068296?et-room-view-source=search-feed
# 1.970 €/mes
# 1.970 €
# 1970.0
# https://badi.com/es/room/1068294?et-room-view-source=search-feed
# 1.970 €/mes
# 1.970 €
# 1970.0
# https://badi.com/es/room/1066780?et-room-view-source=search-feed
# 1.120 €/mes
# 1.120 €
# 1120.0
# https://badi.com/es/room/1066504?et-room-view-source=search-feed
# 1.970 €/mes
# 1.970 €
# 1970.0
# https://badi.com/es/room/1066500?et-room-view-source=search-feed
# 920 €/mes
# 920 €
# 920.0
# https://badi.com/es/room/1009350?et-room-view-source=search-feed
# 1.100 €/mes
# 1.100 €
# 1100.0
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
import nums_from_string

# ser = Service("./chromedriver_win32/chromedriver")   ##### si utilizo esto en lugar de la línea de abajo,
                                                       ##### necesariamente necesito poner options.headless = False
                                                       ##### para que funcione
        
########## para analizar la web con todos los links ##################
ser = Service("./chromedriver")
options = Options()
options.headless = True
options.add_argument("--window-size=1920,1200")
links = []
driver = webdriver.Chrome(options=options, service=ser)
driver.get("https://badi.com/es/s/Barcelona--Espa%C3%B1a?bounds=41.4682974272428,2.22804492421789;41.31703848925413,2.052333262952554&center=41.3873974,2.168568&d=11.164609446567885&city=Barcelona&pid=ChIJ5TCOcRaYpBIRCmZHTz37sEQ&z=12")
asdf = 0
# apts_links = driver.find_element(By.CLASS_NAME, "uw9rr1-2 bqEZRx")

# apts_links = driver.find_elements(By.XPATH, "//div[contains(@class, 'uw9rr1-3 hsUKRR')]")
# for links_pisos in apts_links:
#     links.append(links_pisos.find_elements(By.XPATH,"//a[contains(@data-qa, 'room-card-link')]").get_attribute('href')) 
#     asdf = links_pisos.find_elements(By.XPATH,"//div[contains(@data-qa, 'room-card')]")
#     for asdfasdf in asdf:
#         res = asdfasdf.find_elements(By.XPATH,"//a[contains(@data-qa, 'room-card-link')]")

enlaces = driver.find_elements(By.XPATH,"//a[contains(@data-qa, 'room-card-link')]")

for a in enlaces:
    links.append(a.get_attribute('href')) 

print(len(links))
print(links)
print(type(links))
# Out:
# 20
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
import nums_from_string

# ser = Service("./chromedriver_win32/chromedriver")   ##### si utilizo esto en lugar de la línea de abajo,
                                                       ##### necesariamente necesito poner options.headless = False
                                                       ##### para que funcione

################ para analizar cada habitación #######################
ser = Service("./chromedriver")
options = Options()
options.headless = True
options.add_argument("--window-size=1920,1200")
links = []
driver = webdriver.Chrome(options=options, service=ser)
driver.get("https://badi.com/es/room/626075")

precio_html = driver.find_element(By.XPATH,"//h4[contains(@data-qa, 'room-details-current-price')]").text
tamanho_str = driver.find_element(By.XPATH,"//p[contains(@data-qa, 'section-abstract-icon-label-area')]").text
tamanho_float = float(tamanho_str[:-2])
precio_str = precio_html[:-5]
precio_float = float(precio_str.replace('.', '').replace(',', ''))

print(precio_html)
print(precio_str)
print(tamanho_float)
print(precio_float)
# Out:
# 435 €/mes
# 435
# 18.0
# 435.0

# %%
https://www.spotahome.com/barcelona/for-rent:apartments/120942

# %%
# !pip install selenium undetected-chromedriver

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
import nums_from_string

# ser = Service("./chromedriver_win32/chromedriver")   ##### si utilizo esto en lugar de la línea de abajo,
                                                       ##### necesariamente necesito poner options.headless = False
                                                       ##### para que funcione

################ para analizar cada habitación #######################
ser = Service("./chromedriver")
options = Options()
options.headless = True
options.add_argument("--window-size=1920,1200")
links = []
driver = webdriver.Chrome(options=options, service=ser)
driver.get("https://www.spotahome.com/barcelona/for-rent:apartments/120942")

asdf = driver.find_element(By.XPATH,"//p[contains(@class, 'listing-pricing__square-meter')]").text


print(asdf)
# Out:
# 21.27 €/m2
